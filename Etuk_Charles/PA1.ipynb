# %% [markdown]
# # Math 215 Programming Assignment 1 Template  (30 points)

# %% [markdown]
# ## 1.  Rename this notebook with a naming conversion: Last_First_Math215_HW1.ipynb (3 points)

# %% [markdown]
# ## 2.  Use a print statement to print a greeting message of your choice, similar to our Hello World code  (5 points)

# %% [markdown]
# ## 3.  Complete the quadratic equation exercise we started in class on August 30.  Your program should do each of the following:  (11 points)
# 3.1.  Prompt the user to enter numeric (possibly decimal) values for the coefficients a, b and c
#
# 3.2.  Display the quadratic equation to be solved, with the a, b, and c values substituted in, for example
#
# 7 x^2 + 3.8 x + 2.75 = 0
#
# 3.3.   Display the roots of the quadratic equation ax^2 + bx + c == 0 as complex numbers.  Include a label with the output.

# %%
# You complete this code

a =
b =
c =

# %%
print("The equation")
# Display the equation



print("has solutions (in complex form)")
# Compute and display the solutions

# %% [markdown]
# ## 4.  Color conversions.  (11 points)
# (This problem comes from Introduction to Programming in Python, by Sedgewick, Wayne and Dondero)
#
# Several different formats are used to represent color. For example, the primary format for LCD displays, digital cameras, and web pages, known as the _RGB format_, specifies the level of red (R), green (G), and blue (B) on an integer scale from 0 to 255. The primary format for publishing books and magazines, known as the _CMYK format_, specifies the level of cyan (C), magenta (M), yellow (Y), and black (K) on a real scale from 0.0 to 1.0.
#
# Compose a program that converts RGB to CMYK. Accept three integers - r, g, and b - from the command line and write the equivalent CMYK values:
#
# - If the RGB values are all 0, then the CMY values are all 0 and the K value is 1;
# - otherwise, use these formulas (written mathematically - you need to translate to code, think about the types of r, g, b, c, m, y, k, w):
#
# $w = \max(\frac{r}{255}, \frac{g}{255}, \frac{b}{255})$
#
# $c = \dfrac{w - \frac{r}{255}}{w}$
#
# $m = \dfrac{w - \frac{g}{255}}{w}$
#
# $y = \dfrac{w - \frac{b}{255}}{w}$
#
# $k = 1 - w$

# %% [markdown]
# Check your answers - and see colors
#
# https://g.co/kgs/hdYibu

# %%
# prompt the user and read in integer value for r, g and b





# Compute the values for w, c, m, k, y.  You may assume that r, g, b are not all 0





# Show a labeled display of the values for c, m, k, y

# %% [markdown]
# ## Bonus: (re)name all variables in this notebook in a readable way and with a good naming convention   (3 points)
